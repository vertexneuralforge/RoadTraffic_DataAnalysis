# %%
# import pandas module
import pandas as pd

# create dataframe with 3 columns
data = pd.DataFrame({
    "column1": [12, 23, 45, 67],
    "column2": [67, 54, 32, 1],
    "column3": [34, 23, 56, 23]
}
)
# display dataframe
print(data)

# correlation between column 1 and column2
print(data['column1'].corr(data['column2']))

# correlation between column 2 and column3
print(data['column2'].corr(data['column3']))

# correlation between column 1 and column3
print(data['column1'].corr(data['column3']))
# Out:
#    column1  column2  column3
# 0       12       67       34
# 1       23       54       23
# 2       45       32       56
# 3       67        1       23
# -0.9970476685163736
# 0.07346999975265099
# 0.0

# %%
# create dataframe with 3 columns
data = pd.DataFrame({
    "column1": [12, 23, 45, 67],
    "column2": [67, 54, 32, 1],
    "column3": [34, 23, 56, 23]
}
)
# get correlation between element wise
print(data.corr())
# Out:
#               column1   column2       column3
# column1  1.000000e+00 -0.997048  4.993708e-17
# column2 -9.970477e-01  1.000000  7.347000e-02
# column3  4.993708e-17  0.073470  1.000000e+00

# %%
df = pd.DataFrame()

df['a'] = range(10)
df['b'] = range(10)
df['o'] = range(10)
df['c'] = range(10)
df['dd'] = range(10)


pd.DataFrame([[x, df['a'].corr(df[x])]
              for x in df.columns if x!='a'],
              columns=['var', 'corr'])
# Out:
#   var  corr
# 0   b   1.0
# 1   o   1.0
# 2   c   1.0
# 3  dd   1.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

dfm = pd.read_excel("1_archiveQQ.xlsx")
dfm

# %%
pd.DataFrame([[x, dfm['meteoData.surfaceTemperature.value'].corr(dfm[x])]
              for x in dfm.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

df1 = pd.read_excel("1.xlsx")
df1

pd.DataFrame([[x, df1['meteoData.surfaceTemperature.value'].corr(df1[x])]
              for x in df1.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.213171
# 1               meteoData.snowHeight.value  0.003827
# 2                meteoData.iceHeight.value  0.116373
# 3        meteoData.saltConcentration.value -0.070609
# 4            meteoData.icePercentage.value -0.081812
# 5                 meteoData.friction.value -0.015353
# 6      meteoData.precipitationAmount.value  0.202977
# 7   meteoData.precipitationIntensity.value  0.118781
# 8           meteoData.airTemperature.value  0.801755
# 9                 meteoData.dewPoint.value  0.700882
# 10        meteoData.relativeHumidity.value  0.005473
# 11                meteoData.pressure.value -0.046547
# 12              meteoData.wind.speed.value  0.149709
# 13                meteoData.wind.direction  0.076463

# %%
df3 = pd.read_excel("3.xlsx")

pd.DataFrame([[x, df3['meteoData.surfaceTemperature.value'].corr(df3[x])]
              for x in df3.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.513138
# 1               meteoData.snowHeight.value -0.028753
# 2                meteoData.iceHeight.value  0.296499
# 3        meteoData.saltConcentration.value -0.025462
# 4            meteoData.icePercentage.value  0.062991
# 5                 meteoData.friction.value -0.399405
# 6      meteoData.precipitationAmount.value  0.236359
# 7   meteoData.precipitationIntensity.value  0.128601
# 8           meteoData.airTemperature.value  0.851359
# 9                 meteoData.dewPoint.value  0.775497
# 10        meteoData.relativeHumidity.value  0.237756
# 11                meteoData.pressure.value -0.250534
# 12              meteoData.wind.speed.value  0.042135
# 13                meteoData.wind.direction -0.197818

# %%
df4 = pd.read_excel("4.xlsx")

pd.DataFrame([[x, df4['meteoData.surfaceTemperature.value'].corr(df4[x])]
              for x in df4.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value -0.014421
# 1               meteoData.snowHeight.value  0.002101
# 2                meteoData.iceHeight.value -0.209623
# 3        meteoData.saltConcentration.value -0.352574
# 4            meteoData.icePercentage.value -0.185437
# 5                 meteoData.friction.value -0.236071
# 6      meteoData.precipitationAmount.value -0.077525
# 7   meteoData.precipitationIntensity.value -0.045878
# 8           meteoData.airTemperature.value  0.880635
# 9                 meteoData.dewPoint.value  0.736257
# 10        meteoData.relativeHumidity.value  0.153016
# 11                meteoData.pressure.value -0.160485
# 12              meteoData.wind.speed.value  0.084000
# 13                meteoData.wind.direction -0.091985

# %%
df5 = pd.read_excel("5.xlsx")

pd.DataFrame([[x, df5['meteoData.surfaceTemperature.value'].corr(df5[x])]
              for x in df5.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value -0.001278
# 1               meteoData.snowHeight.value -0.043992
# 2                meteoData.iceHeight.value -0.203383
# 3        meteoData.saltConcentration.value -0.340765
# 4            meteoData.icePercentage.value -0.177345
# 5                 meteoData.friction.value -0.236302
# 6      meteoData.precipitationAmount.value -0.084147
# 7   meteoData.precipitationIntensity.value -0.013866
# 8           meteoData.airTemperature.value  0.885712
# 9                 meteoData.dewPoint.value  0.759716
# 10        meteoData.relativeHumidity.value  0.188935
# 11                meteoData.pressure.value -0.173043
# 12              meteoData.wind.speed.value  0.109871
# 13                meteoData.wind.direction -0.050501

# %%
df6 = pd.read_excel("6.xlsx")

pd.DataFrame([[x, df6['meteoData.surfaceTemperature.value'].corr(df6[x])]
              for x in df6.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.265082
# 1               meteoData.snowHeight.value  0.013854
# 2                meteoData.iceHeight.value  0.216936
# 3        meteoData.saltConcentration.value  0.031869
# 4            meteoData.icePercentage.value  0.213550
# 5                 meteoData.friction.value -0.188125
# 6      meteoData.precipitationAmount.value  0.249054
# 7   meteoData.precipitationIntensity.value  0.069958
# 8           meteoData.airTemperature.value  0.759698
# 9                 meteoData.dewPoint.value  0.624835
# 10        meteoData.relativeHumidity.value  0.021576
# 11                meteoData.pressure.value -0.158926
# 12              meteoData.wind.speed.value  0.204687
# 13                meteoData.wind.direction  0.040960

# %%
df7 = pd.read_excel("7.xlsx")

pd.DataFrame([[x, df7['meteoData.surfaceTemperature.value'].corr(df7[x])]
              for x in df7.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])

# %%
df8 = pd.read_excel("8.xlsx")

pd.DataFrame([[x, df8['meteoData.surfaceTemperature.value'].corr(df8[x])]
              for x in df8.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.067470
# 1               meteoData.snowHeight.value -0.077729
# 2                meteoData.iceHeight.value  0.071146
# 3        meteoData.saltConcentration.value  0.026996
# 4            meteoData.icePercentage.value  0.063272
# 5                 meteoData.friction.value -0.087532
# 6      meteoData.precipitationAmount.value  0.081867
# 7   meteoData.precipitationIntensity.value  0.050236
# 8           meteoData.airTemperature.value  0.810477
# 9                 meteoData.dewPoint.value  0.737652
# 10        meteoData.relativeHumidity.value -0.044518
# 11                meteoData.pressure.value -0.107854
# 12              meteoData.wind.speed.value  0.304618
# 13                meteoData.wind.direction  0.010777

# %%
df9 = pd.read_excel("9.xlsx")

pd.DataFrame([[x, df9['meteoData.surfaceTemperature.value'].corr(df9[x])]
              for x in df9.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.324481
# 1               meteoData.snowHeight.value  0.029445
# 2                meteoData.iceHeight.value  0.217165
# 3        meteoData.saltConcentration.value -0.006288
# 4            meteoData.icePercentage.value  0.183025
# 5                 meteoData.friction.value -0.209122
# 6      meteoData.precipitationAmount.value  0.142688
# 7   meteoData.precipitationIntensity.value  0.015703
# 8           meteoData.airTemperature.value  0.845458
# 9                 meteoData.dewPoint.value  0.663710
# 10        meteoData.relativeHumidity.value  0.104356
# 11                meteoData.pressure.value -0.130625
# 12              meteoData.wind.speed.value  0.272157
# 13                meteoData.wind.direction -0.146381

# %%
df10 = pd.read_excel("10.xlsx")

pd.DataFrame([[x, df10['meteoData.surfaceTemperature.value'].corr(df10[x])]
              for x in df10.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.346585
# 1               meteoData.snowHeight.value -0.005409
# 2                meteoData.iceHeight.value  0.239312
# 3        meteoData.saltConcentration.value  0.056650
# 4            meteoData.icePercentage.value  0.222903
# 5                 meteoData.friction.value -0.362047
# 6      meteoData.precipitationAmount.value  0.117017
# 7   meteoData.precipitationIntensity.value  0.093520
# 8           meteoData.airTemperature.value  0.807169
# 9                 meteoData.dewPoint.value  0.694777
# 10        meteoData.relativeHumidity.value  0.118315
# 11                meteoData.pressure.value -0.117661
# 12              meteoData.wind.speed.value  0.115411
# 13                meteoData.wind.direction -0.063938

# %%
df11 = pd.read_excel("11.xlsx")

pd.DataFrame([[x, df11['meteoData.surfaceTemperature.value'].corr(df11[x])]
              for x in df11.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.185269
# 1               meteoData.snowHeight.value -0.025192
# 2                meteoData.iceHeight.value  0.105284
# 3        meteoData.saltConcentration.value -0.123745
# 4            meteoData.icePercentage.value  0.077325
# 5                 meteoData.friction.value -0.106039
# 6      meteoData.precipitationAmount.value  0.048463
# 7   meteoData.precipitationIntensity.value  0.023761
# 8           meteoData.airTemperature.value  0.691111
# 9                 meteoData.dewPoint.value  0.573778
# 10        meteoData.relativeHumidity.value -0.259052
# 11                meteoData.pressure.value -0.196640
# 12              meteoData.wind.speed.value  0.026319
# 13                meteoData.wind.direction -0.186422

# %%
df12 = pd.read_excel("12.xlsx")

pd.DataFrame([[x, df12['meteoData.surfaceTemperature.value'].corr(df12[x])]
              for x in df12.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.110409
# 1               meteoData.snowHeight.value  0.025610
# 2                meteoData.iceHeight.value  0.006266
# 3        meteoData.saltConcentration.value -0.336531
# 4            meteoData.icePercentage.value -0.049228
# 5                 meteoData.friction.value -0.041521
# 6      meteoData.precipitationAmount.value  0.238843
# 7   meteoData.precipitationIntensity.value  0.063121
# 8           meteoData.airTemperature.value  0.708798
# 9                 meteoData.dewPoint.value  0.589964
# 10        meteoData.relativeHumidity.value  0.051948
# 11                meteoData.pressure.value -0.036708
# 12              meteoData.wind.speed.value  0.224059
# 13                meteoData.wind.direction  0.094319

# %%
df13 = pd.read_excel("13.xlsx")

pd.DataFrame([[x, df13['meteoData.surfaceTemperature.value'].corr(df13[x])]
              for x in df13.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.083358
# 1               meteoData.snowHeight.value -0.132085
# 2                meteoData.iceHeight.value  0.037597
# 3        meteoData.saltConcentration.value  0.011244
# 4            meteoData.icePercentage.value  0.065351
# 5                 meteoData.friction.value -0.053544
# 6      meteoData.precipitationAmount.value  0.157444
# 7   meteoData.precipitationIntensity.value  0.080184
# 8           meteoData.airTemperature.value  0.705651
# 9                 meteoData.dewPoint.value  0.565202
# 10        meteoData.relativeHumidity.value  0.038738
# 11                meteoData.pressure.value -0.028672
# 12              meteoData.wind.speed.value  0.143898
# 13                meteoData.wind.direction  0.078567

# %%
df14 = pd.read_excel("14.xlsx")

pd.DataFrame([[x, df14['meteoData.surfaceTemperature.value'].corr(df14[x])]
              for x in df14.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.086306
# 1               meteoData.snowHeight.value -0.126522
# 2                meteoData.iceHeight.value  0.138951
# 3        meteoData.saltConcentration.value  0.057367
# 4            meteoData.icePercentage.value  0.198459
# 5                 meteoData.friction.value  0.216097
# 6      meteoData.precipitationAmount.value  0.093218
# 7   meteoData.precipitationIntensity.value  0.057920
# 8           meteoData.airTemperature.value  0.823055
# 9                 meteoData.dewPoint.value  0.723363
# 10        meteoData.relativeHumidity.value  0.117883
# 11                meteoData.pressure.value -0.054568
# 12              meteoData.wind.speed.value  0.413890
# 13                meteoData.wind.direction -0.026637

# %%
df15 = pd.read_excel("15.xlsx")

pd.DataFrame([[x, df15['meteoData.surfaceTemperature.value'].corr(df15[x])]
              for x in df15.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.232441
# 1               meteoData.snowHeight.value -0.089232
# 2                meteoData.iceHeight.value  0.046584
# 3        meteoData.saltConcentration.value -0.325362
# 4            meteoData.icePercentage.value -0.111757
# 5                 meteoData.friction.value  0.191683
# 6      meteoData.precipitationAmount.value  0.111966
# 7   meteoData.precipitationIntensity.value  0.042580
# 8           meteoData.airTemperature.value  0.770681
# 9                 meteoData.dewPoint.value  0.707714
# 10        meteoData.relativeHumidity.value  0.184615
# 11                meteoData.pressure.value -0.109110
# 12              meteoData.wind.speed.value  0.271275
# 13                meteoData.wind.direction  0.043953

# %%
df16 = pd.read_excel("16.xlsx")

pd.DataFrame([[x, df16['meteoData.surfaceTemperature.value'].corr(df16[x])]
              for x in df16.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.201325
# 1               meteoData.snowHeight.value -0.116729
# 2                meteoData.iceHeight.value  0.137224
# 3        meteoData.saltConcentration.value -0.228403
# 4            meteoData.icePercentage.value  0.024162
# 5                 meteoData.friction.value  0.123157
# 6      meteoData.precipitationAmount.value  0.226660
# 7   meteoData.precipitationIntensity.value  0.077179
# 8           meteoData.airTemperature.value  0.819547
# 9                 meteoData.dewPoint.value  0.653164
# 10        meteoData.relativeHumidity.value -0.008993
# 11                meteoData.pressure.value -0.023393
# 12              meteoData.wind.speed.value  0.351214
# 13                meteoData.wind.direction -0.024270

# %%
df17 = pd.read_excel("17.xlsx")

pd.DataFrame([[x, df17['meteoData.surfaceTemperature.value'].corr(df17[x])]
              for x in df17.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.205407
# 1               meteoData.snowHeight.value  0.027696
# 2                meteoData.iceHeight.value -0.077780
# 3        meteoData.saltConcentration.value -0.534697
# 4            meteoData.icePercentage.value -0.385984
# 5                 meteoData.friction.value -0.183256
# 6      meteoData.precipitationAmount.value  0.192600
# 7   meteoData.precipitationIntensity.value  0.070010
# 8           meteoData.airTemperature.value  0.802281
# 9                 meteoData.dewPoint.value  0.653010
# 10        meteoData.relativeHumidity.value  0.023206
# 11                meteoData.pressure.value -0.076253
# 12              meteoData.wind.speed.value  0.392129
# 13                meteoData.wind.direction -0.079399

# %%
df18 = pd.read_excel("18.xlsx")

pd.DataFrame([[x, df18['meteoData.surfaceTemperature.value'].corr(df18[x])]
              for x in df18.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.408303
# 1               meteoData.snowHeight.value -0.165976
# 2                meteoData.iceHeight.value  0.151042
# 3        meteoData.saltConcentration.value  0.024915
# 4            meteoData.icePercentage.value  0.119703
# 5                 meteoData.friction.value -0.243497
# 6      meteoData.precipitationAmount.value  0.122818
# 7   meteoData.precipitationIntensity.value  0.040140
# 8           meteoData.airTemperature.value  0.718787
# 9                 meteoData.dewPoint.value  0.594785
# 10        meteoData.relativeHumidity.value  0.066168
# 11                meteoData.pressure.value -0.099498
# 12              meteoData.wind.speed.value  0.214716
# 13                meteoData.wind.direction -0.032954

# %%
df19 = pd.read_excel("19.xlsx")

pd.DataFrame([[x, df19['meteoData.surfaceTemperature.value'].corr(df19[x])]
              for x in df19.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.298680
# 1               meteoData.snowHeight.value  0.001615
# 2                meteoData.iceHeight.value  0.025501
# 3        meteoData.saltConcentration.value -0.403255
# 4            meteoData.icePercentage.value -0.227623
# 5                 meteoData.friction.value  0.045588
# 6      meteoData.precipitationAmount.value  0.220247
# 7   meteoData.precipitationIntensity.value  0.107879
# 8           meteoData.airTemperature.value  0.826608
# 9                 meteoData.dewPoint.value  0.701917
# 10        meteoData.relativeHumidity.value  0.081956
# 11                meteoData.pressure.value -0.056608
# 12              meteoData.wind.speed.value  0.287702
# 13                meteoData.wind.direction -0.086001

# %%
df20 = pd.read_excel("20.xlsx")

pd.DataFrame([[x, df20['meteoData.surfaceTemperature.value'].corr(df20[x])]
              for x in df20.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.184088
# 1               meteoData.snowHeight.value  0.014531
# 2                meteoData.iceHeight.value  0.094818
# 3        meteoData.saltConcentration.value -0.227854
# 4            meteoData.icePercentage.value -0.079438
# 5                 meteoData.friction.value -0.139029
# 6      meteoData.precipitationAmount.value  0.023343
# 7   meteoData.precipitationIntensity.value -0.104316
# 8           meteoData.airTemperature.value  0.778171
# 9                 meteoData.dewPoint.value  0.627976
# 10        meteoData.relativeHumidity.value  0.020778
# 11                meteoData.pressure.value -0.080612
# 12              meteoData.wind.speed.value  0.146995
# 13                meteoData.wind.direction  0.027343

# %%
df21 = pd.read_excel("21.xlsx")

pd.DataFrame([[x, df21['meteoData.surfaceTemperature.value'].corr(df21[x])]
              for x in df21.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.346905
# 1               meteoData.snowHeight.value  0.001039
# 2                meteoData.iceHeight.value  0.202924
# 3        meteoData.saltConcentration.value -0.061765
# 4            meteoData.icePercentage.value  0.007203
# 5                 meteoData.friction.value -0.153837
# 6      meteoData.precipitationAmount.value  0.144591
# 7   meteoData.precipitationIntensity.value  0.063965
# 8           meteoData.airTemperature.value  0.709646
# 9                 meteoData.dewPoint.value  0.571817
# 10        meteoData.relativeHumidity.value  0.018157
# 11                meteoData.pressure.value -0.067653
# 12              meteoData.wind.speed.value  0.227496
# 13                meteoData.wind.direction -0.017557

# %%
df22 = pd.read_excel("22.xlsx")

pd.DataFrame([[x, df22['meteoData.surfaceTemperature.value'].corr(df22[x])]
              for x in df22.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.265040
# 1               meteoData.snowHeight.value  0.014071
# 2                meteoData.iceHeight.value -0.038717
# 3        meteoData.saltConcentration.value -0.522810
# 4            meteoData.icePercentage.value -0.250375
# 5                 meteoData.friction.value -0.275576
# 6      meteoData.precipitationAmount.value  0.161906
# 7   meteoData.precipitationIntensity.value  0.039241
# 8           meteoData.airTemperature.value  0.773869
# 9                 meteoData.dewPoint.value  0.635779
# 10        meteoData.relativeHumidity.value -0.050047
# 11                meteoData.pressure.value -0.060341
# 12              meteoData.wind.speed.value  0.297652
# 13                meteoData.wind.direction -0.007881

# %%
df23 = pd.read_excel("23.xlsx")

pd.DataFrame([[x, df23['meteoData.surfaceTemperature.value'].corr(df23[x])]
              for x in df23.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.248209
# 1               meteoData.snowHeight.value -0.124047
# 2                meteoData.iceHeight.value -0.576582
# 3        meteoData.saltConcentration.value -0.118418
# 4            meteoData.icePercentage.value -0.424498
# 5                 meteoData.friction.value  0.595579
# 6      meteoData.precipitationAmount.value  0.123007
# 7   meteoData.precipitationIntensity.value  0.093059
# 8           meteoData.airTemperature.value  0.674099
# 9                 meteoData.dewPoint.value  0.337886
# 10        meteoData.relativeHumidity.value -0.218967
# 11                meteoData.pressure.value  0.224815
# 12              meteoData.wind.speed.value  0.371038
# 13                meteoData.wind.direction -0.147722

# %%
df24 = pd.read_excel("24.xlsx")

pd.DataFrame([[x, df24['meteoData.surfaceTemperature.value'].corr(df24[x])]
              for x in df24.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.346128
# 1               meteoData.snowHeight.value       NaN
# 2                meteoData.iceHeight.value -0.452996
# 3        meteoData.saltConcentration.value -0.658941
# 4            meteoData.icePercentage.value -0.569920
# 5                 meteoData.friction.value  0.474353
# 6      meteoData.precipitationAmount.value  0.010539
# 7   meteoData.precipitationIntensity.value -0.003507
# 8           meteoData.airTemperature.value  0.877090
# 9                 meteoData.dewPoint.value  0.610422
# 10        meteoData.relativeHumidity.value -0.039729
# 11                meteoData.pressure.value -0.003748
# 12              meteoData.wind.speed.value  0.039175
# 13                meteoData.wind.direction  0.034168

# %%
df25 = pd.read_excel("25.xlsx")

pd.DataFrame([[x, df25['meteoData.surfaceTemperature.value'].corr(df25[x])]
              for x in df25.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.311232
# 1               meteoData.snowHeight.value       NaN
# 2                meteoData.iceHeight.value -0.091586
# 3        meteoData.saltConcentration.value  0.073979
# 4            meteoData.icePercentage.value -0.129771
# 5                 meteoData.friction.value -0.050629
# 6      meteoData.precipitationAmount.value  0.226284
# 7   meteoData.precipitationIntensity.value  0.141780
# 8           meteoData.airTemperature.value  0.889875
# 9                 meteoData.dewPoint.value  0.637101
# 10        meteoData.relativeHumidity.value  0.006813
# 11                meteoData.pressure.value -0.114154
# 12              meteoData.wind.speed.value  0.139042
# 13                meteoData.wind.direction  0.069228

# %%
df26 = pd.read_excel("26.xlsx")

pd.DataFrame([[x, df26['meteoData.surfaceTemperature.value'].corr(df26[x])]
              for x in df26.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.201057
# 1               meteoData.snowHeight.value  0.067879
# 2                meteoData.iceHeight.value  0.083656
# 3        meteoData.saltConcentration.value  0.100547
# 4            meteoData.icePercentage.value  0.091071
# 5                 meteoData.friction.value -0.100518
# 6      meteoData.precipitationAmount.value  0.295987
# 7   meteoData.precipitationIntensity.value  0.159417
# 8           meteoData.airTemperature.value  0.873564
# 9                 meteoData.dewPoint.value  0.620113
# 10        meteoData.relativeHumidity.value  0.025168
# 11                meteoData.pressure.value -0.174399
# 12              meteoData.wind.speed.value  0.259704
# 13                meteoData.wind.direction  0.106134

# %%
df27 = pd.read_excel("27.xlsx")

pd.DataFrame([[x, df27['meteoData.surfaceTemperature.value'].corr(df27[x])]
              for x in df27.columns
              if x!='meteoData.surfaceTemperature.value'],
              columns=['var', 'corr'])
# Out:
#                                        var      corr
# 0          meteoData.waterFilmHeight.value  0.634999
# 1               meteoData.snowHeight.value       NaN
# 2                meteoData.iceHeight.value -0.260573
# 3        meteoData.saltConcentration.value -0.233122
# 4            meteoData.icePercentage.value -0.441606
# 5                 meteoData.friction.value  0.175820
# 6      meteoData.precipitationAmount.value  0.367062
# 7   meteoData.precipitationIntensity.value  0.151462
# 8           meteoData.airTemperature.value  0.922653
# 9                 meteoData.dewPoint.value  0.693078
# 10        meteoData.relativeHumidity.value  0.102977
# 11                meteoData.pressure.value -0.168540
# 12              meteoData.wind.speed.value  0.294012
# 13                meteoData.wind.direction  0.032818
